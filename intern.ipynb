# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv(r"C:\Users\darkk\OneDrive\Desktop\gits\data.csv")

# %%
data.head()
# Out:
#    SNO         REGNO                      NAME  \
# 0    1  110722102001                  Anitha K
# 1    2  110722102002     Aquivna Prishiya Kabi
# 2    3  110722102003                  Baskar D
# 3    4  110722102004  Bellamkonda Venkatamohan
# 4    5  110722102005                 Bharath K
#
#                           Company Name  \
# 0           EDIFY TECHNOLOGIES PVT LTD
# 1               Virtual Tech Services
# 2                 virtual tech service
# 3  Prodigy Infotech, intership program
# 4               Virtual Tech Services
#
#                                  location  INTERN TYPE STARTING DATE  \
# 0  2nd \nfloor Industrial Estate, Guindy.      OFFLINE    05-06-2024
# 1                                Ambattur      OFFLINE    17-06-2024
# 2                                 Ambathur     OFFLINE    17-06-2024
# 3                                      NaN     ONLINE     01-07-2024
# 4                                Ambattur     OFFLINE     17-06-2024
#
# ...

# %%
data.columns
# Out:
# Index(['SNO', 'REGNO', 'NAME', 'Company Name', 'location ', 'INTERN TYPE',
#        'STARTING DATE', 'END DATE', 'DURATION', 'DAYS OF INTERN'],
#       dtype='object')

# %%
data.columns
# Out:
# Index(['SNO', 'REGNO', 'NAME', 'Company Name', 'location ', 'INTERN TYPE',
#        'STARTING DATE', 'END DATE', 'DURATION', 'DAYS OF INTERN'],
#       dtype='object')

# %%
data.isnull()

# %%
data[data.isnull().any(axis=1)] #here [] used to seperate the null value as a subdata and axis=1 used to show the specific row who has null value

# %%
sns.relplot(x="REGNO",y="DAYS OF INTERN",hue='DURATION',data=data)

# %%
plt.rcParams["figure.figsize"] = [8, 3.50]
plt.rcParams["figure.autolayout"] = True
columns = ["REGNO", "DURATION"]
dt = pd.read_csv(r"C:\Users\darkk\OneDrive\Desktop\gits\data.csv", usecols=columns)
plt.plot(dt.REGNO, dt.DURATION)
plt.show()

# %%
x=data['REGNO']
y=data['INTERN TYPE']
plt.xlabel('REGNO',fontsize=18)
plt.ylabel('INTERN TYPE',fontsize=16)
plt.scatter(x,y)

# %%
data['Company Name'].unique()
# Out:
# array(['EDIFY TECHNOLOGIES PVT LTD', 'Virtual Tech Services ',
#        'virtual tech service', 'Prodigy Infotech, intership program',
#        'Technohacks edutech', 'Agnirava space internship program ',
#        'virtual tech services ', 'ILIFE TECHNOLOGIES ',
#        'CODtechitsolutions ', 'codsoft', 'codesoft',
#        'Technohacks EduTech', 'Virtual tech service',
#        'CODTECH IT SOLUTIONS', 'ZF CVCS India Ltd', 'TechnoHacks',
#        'INDSTACK IT CONSULTING PVT LTD  NELLORE ', 'Codsoft',
#        'kaashiv infotech ', 'Bharat',
#        'Edunet Foundation by IBM Skills build',
#        'chatrapathi green Tech software ', 'TechnoHacks '], dtype=object)
